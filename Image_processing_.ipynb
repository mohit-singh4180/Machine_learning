# %% [markdown]
# <a href="https://colab.research.google.com/github/mohit-singh4180/Machine_learning/blob/main/Image_processing_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib.image as im

# %%
image=[[0,255,0,255,0,255,0,255],
       [255,0,255,0,255,0,255,0],
       [0,255,0,255,0,255,0,255],
       [255,0,255,0,255,0,255,0],
       [0,255,0,255,0,255,0,255],
       [255,0,255,0,255,0,255,0],
       [0,255,0,255,0,255,0,255],
       [255,0,255,0,255,0,255,0]]

# %%
##convert into array to display as an image
arr_image=np.array(image)
arr_image
# Out:
# array([[  0, 255,   0, 255,   0, 255,   0, 255],
#        [255,   0, 255,   0, 255,   0, 255,   0],
#        [  0, 255,   0, 255,   0, 255,   0, 255],
#        [255,   0, 255,   0, 255,   0, 255,   0],
#        [  0, 255,   0, 255,   0, 255,   0, 255],
#        [255,   0, 255,   0, 255,   0, 255,   0],
#        [  0, 255,   0, 255,   0, 255,   0, 255],
#        [255,   0, 255,   0, 255,   0, 255,   0]])

# %%
plt.imshow(arr_image)

# %%
###assign color 

plt.imshow(arr_image,cmap='gray')

# %%
image2=[[0,0,0,0,0,0,0,0],
       [0,255,255,0,0,255,255,0],
       [0,255,0,255,255,0,255,0],
       [0,255,0,0,0,0,255,0],
       [0,255,0,0,0,0,255,0],
       [0,255,0,0,0,0,255,0],
       [0,255,0,0,0,0,255,0],
       [0,0,0,0,0,0,0,0]]
##convert into array to display as an image
arr_image2=np.array(image2)

###assign color 

plt.imshow(arr_image2,cmap='gray')

# %%
###Read an image
img=im.imread('mohit.jpg')

# %%
img.shape
# Out:
# (1342, 1546, 3)

# %%
plt.imshow(img)
plt.show()

# %%
###crop the image
plt.imshow(img[500:700,450:1000])

# %%
###create noise using random function

noise=np.random.randint(0,255,(1342,1546,3))
plt.imshow(noise)

# %%
img_with_noise = img+noise
plt.imshow(img_with_noise)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
