# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_excel(r"C:\Users\etisalat\Downloads\Thinkathon_Sample_data.xlsx",sheet_name=1)

# %%
data.head()
# Out:
#    Cust_id  days_since_last_activity  onnet_og_calls  offnet_og_calls  \
# 0        1                         0             383               77
# 1        2                         0               0               73
# 2        3                         0              24               28
# 3        4                         0              73               62
# 4        5                         0             344                0
#
#    int_og_calls  total_data_sessions  total_discounted_calls  onnet_og_mins  \
# 0             0                  133                       0    2001.500000
# 1             0                    2                      73       0.000000
# 2             0                   99                       4      26.350000
# 3             1                  245                       1      67.916667
# 4             0                    3                       0     503.466667
#
#    offnet_og_mins  int_og_mins         ...          days_since_last_recharge  \
# ...

# %%
data.shape
# Out:
# (200, 49)

# %%
data2=data[["Cust_id","days_since_last_activity","days_since_last_recharge"]]

# %%
data2.head()
# Out:
#    Cust_id  days_since_last_activity  days_since_last_recharge
# 0        1                         0                      1053
# 1        2                         0                       111
# 2        3                         0                        24
# 3        4                         0                       158
# 4        5                         0                       102

# %%
plt.figure(figsize=(12,8))
plt.scatter(data2["days_since_last_recharge"],data2["days_since_last_activity"])
plt.xlabel("days_since_last_recharge")
plt.ylabel("days_since_last_activity")
plt.show()

# %%
data3=data[(data["days_since_last_recharge"]>90) & (data["days_since_last_activity"]>20)]
data3
# Out:
#      Cust_id  days_since_last_activity  onnet_og_calls  offnet_og_calls  \
# 45        46                        24               0                0
# 58        59                        25               0                0
# 70        71                        67               0                0
# 135      136                        45               0                0
#
#      int_og_calls  total_data_sessions  total_discounted_calls  onnet_og_mins  \
# 45              2                    0                       2            0.0
# 58              0                    0                       0            0.0
# 70              0                    0                       0            0.0
# 135             0                    0                       0            0.0
#
#      offnet_og_mins  int_og_mins         ...          \
# 45              0.0    22.883333         ...
# 58              0.0     0.000000         ...
# 70              0.0     0.000000         ...
# ...

# %%
plt.figure(figsize=(12,8))
plt.scatter(data2["days_since_last_recharge"],data2["days_since_last_activity"],c="black")
plt.scatter(data3["days_since_last_recharge"],data3["days_since_last_activity"],c="red")
plt.xlabel("days_since_last_recharge")
plt.ylabel("days_since_last_activity")
plt.show()
